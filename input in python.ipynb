# %%
n=input()
n
# Out:
# 22
# '22'

# %%
type(n)
# Out:
# str

# %%
n=input()
n

# %%
n1 = input("enter your age:")
n2 = int(n1)
# Out:
# enter your age:19

# %%
n=float(input("enter your age:"))
n
# Out:
# enter your age:19
# 19.0

# %%
name = input("enter your name:")
print ("it was nice talking to you"+ name +"!")
# Out:
# enter your name:Ashirbad
# it was nice talking to youAshirbad!

# %%
age = input("enter your age:")
print ("hey , you are already"+ age +"years old!" + name + "!")
# Out:
# enter your age:22
# hey , you are already22years old!Ashirbad!
