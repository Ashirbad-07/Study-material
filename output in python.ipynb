# %%
print(2)
# Out:
# 2

# %%
print("rama")
# Out:
# rama

# %%
print("asffsfwe 12!@#$")
# Out:
# asffsfwe 12!@#$

# %%
b = 20
print(b)
# Out:
# 20

# %%
siva=10
print(siva)
# Out:
# 10

# %%
print("siva")
# Out:
# siva

# %%
a = 10
b = 20
c = 30
print (a+b+c)
# Out:
# 60

# %%
a='2'
print(a)
type(a)
# Out:
# 2
# str

# %%
a = 10
b = 20
c=a+b
print(c)
# Out:
# 30

# %%
a = 10
b = 20
print(a+b)
# Out:
# 30

# %%
print(10+20)
# Out:
# 30

# %%
a = 10
b = 20
c = 30
d = 4
print(a,b,c,d)
# Out:
# 10 20 30 4

# %%
first_name = 'Siva'
last_name = 'ram'

# %%
print("Name", last_name, first_name)
# Out:
# Name ram Siva

# %%
print("My first name is:", first_name, "and last name is:", last_name)
# Out:
# My first name is: Siva and last name is: ram

# %%
print("Hello {name} {greeting} {name}".format(name="satish", greeting="Good Morning"))
# Out:
# Hello satish Good Morning satish

# %%
#we can combine positional arguments with keyword arguments
print('The story of {}, {}, and {other}'.format('Bill', 'Manfred', other= 'Geor'))
# Out:
# The story of Bill, Manfred, and Geor

# %%
num = 12
name = 'siva'
print('My number is: {} and my name is: {}'.format(num, name))
print('My number is: {num} and my name is: {name}'.format(num=num, name=name))
# Out:
# My number is: 12 and my name is: siva
# My number is: 12 and my name is: siva
