# %%
a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
add = a + b
sub=a-b
mult=a*b
div=a/b
mod=a%b
print("ADD:", add)
print("Sum: {0}, Diff: {1}, Mult:{2}, Div:{3}, Mod: {4}".format(add, sub), mult, div, mod)
# Out:
# Enter the value of a: 25
# Enter the value of b: 5
# ADD: 30
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-20e0a79c3424> in <cell line: 9>()
#       7 mod=a%b
#       8 print("ADD:", add)
# ----> 9 print("Sum: {0}, Diff: {1}, Mult:{2}, Div:{3}, Mod: {4}".format(add, sub), mult, div, mod)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
print("Sum: {}, Diff: {}, Mult:{}, Div:{}, Mod: {}".format(add, sub, mul, div, mod))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-06d9a0c9f67f> in <cell line: 1>()
# ----> 1 print("Sum: {}, Diff: {}, Mult:{}, Div:{}, Mod: {}".format(add, sub, mul, div, mod))
#
# NameError: name 'mul' is not defined

# %%
print("Sum: %d, Diff: %d, Mult: %d, Div:%15.6f, Mod:%d" % (add, sub, mul, div, mod))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-62be0ded608c> in <cell line: 1>()
# ----> 1 print("Sum: %d, Diff: %d, Mult: %d, Div:%15.6f, Mod:%d" % (add, sub, mul, div, mod))
#
# NameError: name 'mul' is not defined

# %%
print('{0: <4} | {1:^4} | {2:^4} | {3:>4}'.format('Sum', 'Diff', 'Mult', 'Div'))
print('{0:<4} | {1:^4} | {2:^4} | {3:>4}'.format(add, sub, mult, div))
# Out:
# Sum  | Diff | Mult |  Div
# 30   |  20  | 125  |  5.0

# %%
print("{0: <4} | {2:^4} | {1:^4} | {3:>4}".format('Sum', 'Diff', 'Mult', 'Div'))
print("{0:<4} | {2:^4} | {1:^4} | {3:>4}".format(add, sub, mult, div))
# Out:
# Sum  | Mult | Diff |  Div
# 30   | 125  |  20  |  5.0

# %%
a="Master Class"
print(f"Welcome to Python {a} !") #Formatting string Literals
# Out:
# Welcome to Python Master Class !

# %%
f = input("Enter a company name")
g = input("Enter the number of emplyees - ")
print("The name of the company is and the number of emplyees are ",f,g)
# Out:
# Enter a company nameocac
# Enter the number of emplyees - 36
# The name of the company is and the number of emplyees are  ocac 36

# %%
print("The name of the company is", f, "and the number of employees are", g)
# Out:
# The name of the company is ocac and the number of employees are 36

# %%
print(f"The name of the company is {f} and the number of employees are {g}")
# Out:
# The name of the company is ocac and the number of employees are 36
