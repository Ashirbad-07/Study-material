# %%
print('Hi!')
print('siva')
# Out:
# Hi!
# siva

# %%
if 1>2:
    print('yes')

# %%
if 1>2:
print('Hi!')
print("siva")
# Out:
#   File "<ipython-input-4-b4d3c0ffd191>", line 2
#     print('Hi!')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1
