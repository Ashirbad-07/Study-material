# %%
import math

# Addition
print(1 + 3 + 5)
# Out:
# 9

# %%
#subtraction
print(10 - 5)
#
# Out:
# 5

# %%
2 + 3
# Out:
# 5

# %%
# Division
6/2
# Out:
# 3.0

# %%
##	power/exponent
10**2
# Out:
# 100

# %%
10/3
# Out:
# 3.3333333333333335

# %%
#	ModuLo --> remainder
10%3
# Out:
# 1

# %%
#	parantasis
(2+3)*4
# Out:
# 20

# %%
## MathematicaL operation with VariatqAssigment a=10
a=10
b=20
print(a*b)
print(a/b)
# Out:
# 200
# 0.5

# %%
a-b*a/b+a ##80DMAS
# Out:
# 10.0

# %%
(2*(2+6 ) )
# Out:
# 16

# %%
8//6%5+2**3-2
# Out:
# 7

# %%
# greater than
45>34
# Out:
# True

# %%
# Less than
56<23
# Out:
# False

# %%
3*3 < 4*2
# Out:
# False

# %%
#	not equaL
3!=4
# Out:
# True

# %%
#greaterthan or equaLto
3>=4
# Out:
# False

# %%
#Lessthan equaLto
5 <= 4
# Out:
# False

# %%
bin(100)
# Out:
# '0b1100100'

# %%
a=10
a # is a simple assignment operator that assigns the value 10 on the right to the variable a on the Left.
# Out:
# 10

# %%
(2 == 2) and (3 < 4) or (4 == 4)
# Out:
# True

# %%
my_str = 'Ashirbad'

# %%
(2 == 2) and (3 <= 4) or (4 == 4)
# Out:
# True

# %%
not True
# Out:
# False

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(5>6) or 2 < 3
# Out:
# True

# %%
7&9
# Out:
# 1

# %%
719
# Out:
# 719

# %%
print# 1 1 1 result)
#1371wise AND
a = 3  # 0 1 //
b=5	#	/	0 /

print(a & b) # 0 0 1 resuLt
# Out:
# 1
